# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("googleplaystore.csv",nrows=500)
df
# Out:
#                                                    App        Category  \
# 0       Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                  Coloring book moana  ART_AND_DESIGN
# 2    U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                Sketch - Draw & Paint  ART_AND_DESIGN
# 4                Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ..                                                 ...             ...
# 495                                  Clover Dating App          DATING
# 496                     Black People Meet Singles Date          DATING
# 497  Mingle2 - Free Online Dating & Singles Chat Rooms          DATING
# 498              Free Dating App & Flirt Chat - Cheers          DATING
# 499                     stranger chat - anonymous chat          DATING
#
#      Rating  Reviews  Size     Installs  Type Price Content Rating  \
# ...

# %%
x=df["Rating"]
y=df["Reviews"]

plt.scatter(x,y)

# %%
plt.title("google play store app scatter",fontsize=10)
plt.xlabel("Rating",fontsize=10)
plt.ylabel("Rewiews",fontsize=10)
x=df["Rating"]
y=df["Reviews"]

plt.scatter(x,y)

# %%
plt.title("google play store app scatter",fontsize=10)
plt.scatter(x,y,color="r",marker="*",linewidths=5)
plt.xlabel("Rating",fontsize=10)
plt.ylabel("Rewiews",fontsize=10)
x=df["Rating"]
y=df["Reviews"]
