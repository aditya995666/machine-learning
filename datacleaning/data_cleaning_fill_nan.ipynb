# %%
import pandas  as pd
import matplotlib.pyplot as plt
import seaborn as ans

# %%
df=pd.read_csv(r"train.csv")

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.head(6)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 5         Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
# 5     10   2009        WD         Normal     143000
#
# [6 rows x 81 columns]

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df.fillna(method="ffill",axis=1)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3408\3252714673.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill",axis=1)
#         Id MSSubClass MSZoning LotFrontage LotArea Street Alley LotShape  \
# 0        1         60       RL        65.0    8450   Pave  Pave      Reg
# 1        2         20       RL        80.0    9600   Pave  Pave      Reg
# 2        3         60       RL        68.0   11250   Pave  Pave      IR1
# 3        4         70       RL        60.0    9550   Pave  Pave      IR1
# 4        5         60       RL        84.0   14260   Pave  Pave      IR1
# ...    ...        ...      ...         ...     ...    ...   ...      ...
# 1455  1456         60       RL        62.0    7917   Pave  Pave      Reg
# 1456  1457         20       RL        85.0   13175   Pave  Pave      Reg
# 1457  1458         70       RL        66.0    9042   Pave  Pave      Reg
# 1458  1459         20       RL        68.0    9717   Pave  Pave      Reg
# 1459  1460         20       RL        75.0    9937   Pave  Pave      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0      0      0           0       0
# 1            Lvl    AllPub  ...        0      0      0           0       0
# 2            Lvl    AllPub  ...        0      0      0           0       0
# 3            Lvl    AllPub  ...        0      0      0           0       0
# 4            Lvl    AllPub  ...        0      0      0           0       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0      0      0           0       0
# 1456         Lvl    AllPub  ...        0      0  MnPrv       MnPrv       0
# 1457         Lvl    AllPub  ...        0      0  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0      0      0           0       0
# 1459         Lvl    AllPub  ...        0      0      0           0       0
#
#      MoSold YrSold SaleType SaleCondition SalePrice
# 0         2   2008       WD        Normal    208500
# 1         5   2007       WD        Normal    181500
# 2         9   2008       WD        Normal    223500
# 3         2   2006       WD       Abnorml    140000
# 4        12   2008       WD        Normal    250000
# ...     ...    ...      ...           ...       ...
# 1455      8   2007       WD        Normal    175000
# 1456      2   2010       WD        Normal    210000
# 1457      5   2010       WD        Normal    266500
# 1458      4   2010       WD        Normal    142125
# 1459      6   2008       WD        Normal    147500
#
# [1460 rows x 81 columns]

# %%
df.fillna(method='bfill',axis=1)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3408\3381026564.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill',axis=1)
#         Id MSSubClass MSZoning LotFrontage LotArea Street Alley LotShape  \
# 0        1         60       RL        65.0    8450   Pave   Reg      Reg
# 1        2         20       RL        80.0    9600   Pave   Reg      Reg
# 2        3         60       RL        68.0   11250   Pave   IR1      IR1
# 3        4         70       RL        60.0    9550   Pave   IR1      IR1
# 4        5         60       RL        84.0   14260   Pave   IR1      IR1
# ...    ...        ...      ...         ...     ...    ...   ...      ...
# 1455  1456         60       RL        62.0    7917   Pave   Reg      Reg
# 1456  1457         20       RL        85.0   13175   Pave   Reg      Reg
# 1457  1458         70       RL        66.0    9042   Pave   Reg      Reg
# 1458  1459         20       RL        68.0    9717   Pave   Reg      Reg
# 1459  1460         20       RL        75.0    9937   Pave   Reg      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0      0      0           0       0
# 1            Lvl    AllPub  ...        0      0      0           0       0
# 2            Lvl    AllPub  ...        0      0      0           0       0
# 3            Lvl    AllPub  ...        0      0      0           0       0
# 4            Lvl    AllPub  ...        0      0      0           0       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0      0      0           0       0
# 1456         Lvl    AllPub  ...        0  MnPrv  MnPrv           0       0
# 1457         Lvl    AllPub  ...        0  GdPrv  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0      0      0           0       0
# 1459         Lvl    AllPub  ...        0      0      0           0       0
#
#      MoSold YrSold SaleType SaleCondition SalePrice
# 0         2   2008       WD        Normal    208500
# 1         5   2007       WD        Normal    181500
# 2         9   2008       WD        Normal    223500
# 3         2   2006       WD       Abnorml    140000
# 4        12   2008       WD        Normal    250000
# ...     ...    ...      ...           ...       ...
# 1455      8   2007       WD        Normal    175000
# 1456      2   2010       WD        Normal    210000
# 1457      5   2010       WD        Normal    266500
# 1458      4   2010       WD        Normal    142125
# 1459      6   2008       WD        Normal    147500
#
# [1460 rows x 81 columns]

# %%
df["MSSubClass"].mode()[0]
data["MSSSubClass"].fillna(df["MSSubClass"].mode()[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 df["MSSubClass"].mode()[0]
# ----> 2 data["MSSSubClass"].fillna(df["MSSubClass"].mode()[0])
#
# NameError: name 'data' is not defined
