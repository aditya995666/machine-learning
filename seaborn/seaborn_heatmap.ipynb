# %%
import  pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
arr_2d=np.linspace(1,6,12).reshape(4,3)
arr_2d
# Out:
# array([[1.        , 1.45454545, 1.90909091],
#        [2.36363636, 2.81818182, 3.27272727],
#        [3.72727273, 4.18181818, 4.63636364],
#        [5.09090909, 5.54545455, 6.        ]])

# %%
sns.heatmap(arr_2d)
# Out:
# <Axes: >

# %%
df=pd.read_csv("Who_is_responsible_for_global_warming.csv")
df
# Out:
#           Country Name Country Code                          Indicator Name  \
# 0        United States          USA  CO2 emissions (metric tons per capita)
# 1       United Kingdom          GBR  CO2 emissions (metric tons per capita)
# 2                India          IND  CO2 emissions (metric tons per capita)
# 3                China          CHN  CO2 emissions (metric tons per capita)
# 4   Russian Federation          RUS  CO2 emissions (metric tons per capita)
# 5            Australia          AUS  CO2 emissions (metric tons per capita)
# 6               France          FRA  CO2 emissions (metric tons per capita)
# 7              Germany          DEU  CO2 emissions (metric tons per capita)
# 8               Canada          CAN  CO2 emissions (metric tons per capita)
# 9               Brazil          BRA  CO2 emissions (metric tons per capita)
# 10           Argentina          ARG  CO2 emissions (metric tons per capita)
# ...

# %%
df1=df.drop(columns=["country code","indicator name","indicator code"],axis=1).set_index("country name")
df1.head(6)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df1=df.drop(columns=["country code","indicator name","indicator code"],axis=1).set_index("country name")
#       2 df1.head(6)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
# ...

# %%
plt.figure(figsize=(16,9))
sns.heatmap(df1)
# Out:
# <Axes: ylabel='country'>

# %%
plt.figure(figsize=(16,9))

# %%
df1=df.drop(columns=["Indicator Code","Indicator Name","Country Code"],axis=0).set_index("Country Name")
df1.head(6)
# Out:
#                          2000       2001       2002       2003       2004  \
# Country Name
# United States       20.178751  19.636505  19.613404  19.564105  19.658371
# United Kingdom       9.199549   9.233175   8.904123   9.053278   8.989140
# India                0.979870   0.971698   0.967381   0.992392   1.025028
# China                2.696862   2.742121   3.007083   3.524074   4.037991
# Russian Federation  10.627121  10.669603  10.715901  11.090647  11.120627
# Australia           17.200610  16.733367  17.370452  16.901959  17.026515
#
#                          2005       2006       2007       2008       2009  \
# Country Name
# United States       19.591885  19.094067  19.217898  18.461764  17.157738
# United Kingdom       8.982939   8.898710   8.617164   8.424424   7.574622
# India                1.068563   1.121982   1.193210   1.310098   1.431844
# China                4.523178   4.980314   5.334910   5.701915   6.010102
# ...

# %%
sns.heatmap(df1)
# Out:
# <Axes: ylabel='Country Name'>

# %%
sns.heatmap(df1,vmin=True,vmax=True)
# Out:
# <Axes: ylabel='Country Name'>

# %%
sns.heatmap(df1,cmap="coolwarm")
# Out:
# <Axes: ylabel='Country Name'>

# %%
plt.figure(figsize=(16,9))
sns.heatmap(df1,annot=True)
# Out:
# <Axes: ylabel='Country Name'>

# %%
annot_kws = {"fontsize":10,'rotation':'vertical'}
sns.heatmap(df1,annot=True,annot_kws=annot_kws)
# Out:
# <Axes: ylabel='Country Name'>
